# %% [markdown]
# BELOW CODE WRITTEN BY PRATHAM

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# Read csv files
members = pd.read_csv('/content/drive/MyDrive/SNA /datasets-1/members.csv', index_col='member_id')
groups = pd.read_csv('/content/drive/MyDrive/SNA /datasets-1/groups.csv', index_col='group_id')
events = pd.read_csv('/content/drive/MyDrive/SNA /datasets-1/events.csv', index_col='event_id')
meta_data = pd.read_csv('/content/drive/MyDrive/SNA /Dataset/meta-groups.csv')
members_df = pd.read_csv('/content/drive/MyDrive/SNA /datasets-1/member-to-group-edges.csv')
rsvps = pd.read_csv('/content/drive/MyDrive/SNA /Dataset/rsvps.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
edges = pd.read_csv('/content/drive/MyDrive/SNA /Dataset/member-edges.csv')
g = nx.from_pandas_edgelist(edges, 'member1', 'member2', 'weight')
print('There are', len(g.nodes), 'nodes and', len(g.edges), 'edges.')
# Out:
# There are 11372 nodes and 1176368 edges.

# %%
#Degree distribution of member-member graph
def plot_degree_dist(G):
    degrees = [G.degree(n) for n in G.nodes()]
    plt.hist(degrees)
    plt.xlabel("Degree")
    plt.ylabel("No. of nodes")
    plt.show()
    
plot_degree_dist(g)

# %%
# Get NashJs events
nashjs_id = 10016242
nashjs_event_ids = events.loc[events.group_urlname == 'nashjs'].index.tolist()

# Get list of unique member_ids attending a Nashjs event
nashjs_rsvps = rsvps.loc[rsvps.event_id.isin(nashjs_event_ids)]
nashjs_member_ids = nashjs_rsvps['member_id'].unique().tolist()

# nashjs_member_ids = rsvps.loc[rsvps.event_id.isin(nashjs_events), 'member_id'].unique()

print('There are {} NashJs events.'.format(len(nashjs_event_ids)))
print('There are {} NashJS attendees.'.format(len(nashjs_member_ids)))
# Out:
# There are 23 NashJs events.
# There are 760 NashJS attendees.

# %%
#Graph of member-events data
g = nx.from_pandas_edgelist(nashjs_rsvps, 
                             source='member_id', 
                             target='event_id')

# Add "Node Type" attribute 
node_type_dict = {n: ('member' if n in nashjs_member_ids else 'event') 
                        for n in g.nodes}
nx.set_node_attributes(g, node_type_dict, 'node_type')

# %%
pos = nx.spring_layout(g)
colors = ['xkcd:blue' if g.nodes[n]['node_type'] == 'member'
              else 'xkcd:bright red' for n in g.nodes]
nx.draw_networkx(g, pos, node_color=colors, node_size=8,
                       with_labels=False)

# Draw a legend
handles = [plt.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="xkcd:blue"), 
           plt.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="xkcd:bright red")]
plt.legend(handles, ['Members', 'Events'], frameon=False)
# ax = plt.gca()
# ax.set_aspect(1)
# ax.axis('off')

plt.show()

# %%
#Getting member-member graph from member-event graph
member_nodes, event_nodes = nx.bipartite.sets(g)
# print('There are {} members and {} events.'.format(len(member_nodes), len(event_nodes)))

# %%
# For member-member graph, nodes represent member_id and edges represent shared events between 2 members
gm = nx.bipartite.weighted_projected_graph(g,member_nodes,False)    

ge = nx.bipartite.weighted_projected_graph(g, event_nodes, False)
# pos = nx.spring_layout(ge)
# nx.draw_networkx(ge, pos, node_size=8,
#                        with_labels=False)
# plt.show()

# %%
#Find no of events attended by a particular member and degree of that member and betweeness centrality

# Initialize df
df_members = pd.DataFrame(index=gm.nodes)
df_members['num_events'] = pd.Series(dict(g.degree))   
df_members['degree'] = pd.Series(dict(gm.degree))
df_members['centrality'] = pd.Series(nx.betweenness_centrality(gm))

df_members.head()
# Out:
#            num_events  degree  centrality
# 509953              4     254    0.001167
# 202010629           1      89    0.000000
# 221577224           1     140    0.000000
# 236163083           2     181    0.000245
# 216782860           2     198    0.000345

# %%
#Find which members have highest degree and centrality
famous_members = df_members.sort_values(by='centrality', ascending=False).head().join(members)
famous_members[['name', 'city', 'num_events', 'degree', 'centrality']]
# Out:
#                      name       city  num_events  degree  centrality
# 8111102    William Golden  Nashville          23     759    0.039739
# 26576702        Ryan Macy  Nashville          23     759    0.039739
# 177418312        Justin M  Hermitage          20     720    0.033753
# 71851852     Rick Murdock   Franklin          17     677    0.028142
# 85557392    Michael Knell  Nashville          17     660    0.025074

# %%
# After this, we can compare and analyse about NashJs with whole meetup network i.e.
# In whole meetup,which members are of NashJS grps having highest betweenness centrality
#  We can find that top members have participated in which other grps events apart from nashjs grp events
# We can find details of top members of whole nashville meetup network
# We can find which grps have highest centrality in whole meetup network
# We can find and plot most clustered grps in this network

# %%
#total members and events
print("There are {} unique members and {} unique events.".format(len(rsvps.member_id.unique()), 
                                                                 len(rsvps.event_id.unique())))
# Out:
# There are 24631 unique members and 19031 unique events.

# %%
# Mapping of members with events and groups
member_events = {}
for index, row in rsvps.iterrows():
    event_id = row['event_id']
    group_id = row['group_id']
    member = row['member_id']
    if member not in member_events:
      member_events[member] = []
    member_events[member].append((event_id, group_id))

# Mapping event_id and member_ids of that event 
event_members = {}
for index, row in rsvps.iterrows():
    event_id = row['event_id']
    member = row['member_id']
    if event_id not in event_members:
      event_members[event_id] = []
    event_members[event_id].append(member)

# Mapping of group_id to member_id
group_members = {}
for index, row in members_df.iterrows():
    group_id = row['group_id']
    member_id = row['member_id']
    if group_id not in group_members:
      group_members[group_id] = []
    group_members[group_id].append(member_id)

# Determine how many members of each group participated in each event
event_participation = {}
for event_id, group_id in rsvps[['event_id', 'group_id']].itertuples(index=False):
    own_group_count = 0
    other_group_count = 0
    for member in event_members[event_id]:
        if member in group_members[group_id]:
            own_group_count += 1
        else:
            other_group_count += 1
    event_participation[event_id] = {'own_group_count': own_group_count, 'other_group_count': other_group_count}

# Print the results
for event_id, participation in event_participation.items():
    print(f"Event {event_id}: {participation['own_group_count']} members of own group participated and {participation['other_group_count']} members of other groups participated.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Event 240611916: 10 members of own group participated and 0 members of other groups participated.
# Event 240919229: 6 members of own group participated and 0 members of other groups participated.
# Event 241564481: 5 members of own group participated and 0 members of other groups participated.
# Event 240813070: 2 members of own group participated and 0 members of other groups participated.
# Event 240530523: 13 members of own group participated and 0 members of other groups participated.
# Event 240611881: 9 members of own group participated and 0 members of other groups participated.
# Event 240871831: 2 members of own group participated and 0 members of other groups participated.
# Event 239887760: 14 members of own group participated and 0 members of other groups participated.
# Event 240284668: 2 members of own group participated and 0 members of other groups participated.
# Event 239901663: 3 members of own group participated and 0 members of other groups participated.
# Event 239453946: 6 members of own group participated and 0 members of other groups participated.
# Event 235011104: 2 members of own group participated and 0 members of other groups participated.
# Event 238725122: 8 members of own group participated and 0 members of other groups participated.
# Event 238649152: 7 members of own group participated and 0 members of other groups participated.
# Event 238801669: 4 members of own group participated and 0 members of other groups participated.
# Event 238481910: 7 members of own group participated and 0 members of other groups participated.
# Event 237748960: 14 members of own group participated and 0 members of other groups participated.
# Event 237687956: 9 members of own group participated and 0 members of other groups participated.
# Event 236620495: 2 members of own group participated and 0 members of other groups participated.
# Event 237202886: 20 members of own group participated and 0 members of other groups participated.
# Event 237203312: 11 members of own group participated and 0 members of other groups participated.
# Event 237149622: 3 members of own group participated and 0 members of other groups participated.
# Event 236640441: 12 members of own group participated and 0 members of other groups participated.
# Event 236483204: 7 members of own group participated and 0 members of other groups participated.
# Event 236024044: 4 members of own group participated and 0 members of other groups participated.
# Event 235890717: 6 members of own group participated and 0 members of other groups participated.
# Event 236100963: 1 members of own group participated and 0 members of other groups participated.
# Event 235427286: 4 members of own group participated and 0 members of other groups participated.
# Event 235589235: 2 members of own group participated and 0 members of other groups participated.
# Event 235608325: 1 members of own group participated and 0 members of other groups participated.
# Event 235608379: 1 members of own group participated and 0 members of other groups participated.
# Event 235608422: 1 members of own group participated and 0 members of other groups participated.
# Event 235343693: 5 members of own group participated and 0 members of other groups participated.
# Event 235232863: 2 members of own group participated and 0 members of other groups participated.
# Event 235008435: 3 members of own group participated and 0 members of other groups participated.
# Event 234835509: 13 members of own group participated and 0 members of other groups participated.
# Event 233952908: 2 members of own group participated and 0 members of other groups participated.
# Event 234607986: 5 members of own group participated and 0 members of other groups participated.
# Event 234470174: 5 members of own group participated and 0 members of other groups participated.
# Event 233666302: 5 members of own group participated and 0 members of other groups participated.
# Event 234296423: 4 members of own group participated and 0 members of other groups participated.
# Event 233915037: 10 members of own group participated and 0 members of other groups participated.
# Event 233559216: 14 members of own group participated and 0 members of other groups participated.
# Event 234135990: 3 members of own group participated and 0 members of other groups participated.
# Event 233914847: 14 members of own group participated and 0 members of other groups participated.
# Event 233547540: 4 members of own group participated and 0 members of other groups participated.
# Event 233499856: 6 members of own group participated and 0 members of other groups participated.
# Event 233499640: 2 members of own group participated and 0 members of other groups participated.
# Event 233499505: 3 members of own group participated and 0 members of other groups participated.
# Event 244453107: 6 members of own group participated and 0 members of other groups participated.
# Event ggbgmnywnbvb: 17 members of own group participated and 0 members of other groups participated.
# Event 243499636: 15 members of own group participated and 0 members of other groups participated.
# Event vptvsnywmbkc: 9 members of own group participated and 0 members of other groups participated.
# Event ggbgmnywmbxb: 23 members of own group participated and 0 members of other groups participated.
# Event 241813594: 22 members of own group participated and 0 members of other groups participated.
# Event llxkxlywkbwb: 37 members of own group participated and 0 members of other groups participated.
# Event llxkxlywjbzb: 14 members of own group participated and 0 members of other groups participated.
# Event kkrntlywhbpc: 13 members of own group participated and 0 members of other groups participated.
# Event llxkxlywhbtb: 18 members of own group participated and 0 members of other groups participated.
# Event kkrntlywgbjc: 13 members of own group participated and 0 members of other groups participated.
# Event llxkxlywgbwb: 16 members of own group participated and 0 members of other groups participated.
# Event kkrntlywfbmc: 8 members of own group participated and 0 members of other groups participated.
# Event llxkxlywfbbc: 11 members of own group participated and 0 members of other groups participated.
# Event kkrntlywdbdc: 11 members of own group participated and 0 members of other groups participated.
# Event llxkxlywdbbc: 31 members of own group participated and 0 members of other groups participated.
# Event kkrntlywcbhc: 17 members of own group participated and 0 members of other groups participated.
# Event llxkxlywcbvb: 21 members of own group participated and 0 members of other groups participated.
# Event kkrntlyvpbnc: 10 members of own group participated and 0 members of other groups participated.
# Event llxkxlyvpbcc: 14 members of own group participated and 0 members of other groups participated.
# Event kkrntlyvnbjc: 15 members of own group participated and 0 members of other groups participated.
# Event 234840297: 9 members of own group participated and 0 members of other groups participated.
# Event llxkxlyvnbwb: 18 members of own group participated and 0 members of other groups participated.
# Event kkrntlyvmblc: 8 members of own group participated and 0 members of other groups participated.
# Event 233671019: 7 members of own group participated and 0 members of other groups participated.
# Event kkrntlyvlbpc: 13 members of own group participated and 0 members of other groups participated.
# Event qghpslyvlbtb: 14 members of own group participated and 0 members of other groups participated.
# Event 232713243: 14 members of own group participated and 0 members of other groups participated.
# Event kkrntlyvkbkc: 13 members of own group participated and 0 members of other groups participated.
# Event qghpslyvkbxb: 10 members of own group participated and 0 members of other groups participated.
# Event 231699474: 21 members of own group participated and 0 members of other groups participated.
# Event kkrntlyvjbmc: 10 members of own group participated and 0 members of other groups participated.
# Event qghpslyvjbbc: 20 members of own group participated and 0 members of other groups participated.
# Event ncxnflyvhbhc: 16 members of own group participated and 0 members of other groups participated.
# Event ngtsqlyvhbvb: 18 members of own group participated and 0 members of other groups participated.
# Event 230551983: 13 members of own group participated and 0 members of other groups participated.
# Event ncxnflyvgbkc: 10 members of own group participated and 0 members of other groups participated.
# Event ngtsqlyvgbxb: 20 members of own group participated and 0 members of other groups participated.
# Event ncxnflyvfbnc: 12 members of own group participated and 0 members of other groups participated.
# Event djmfzhyvfbcc: 25 members of own group participated and 0 members of other groups participated.
# Event 228259214: 25 members of own group participated and 0 members of other groups participated.
# Event ncxnflyvdbgc: 11 members of own group participated and 0 members of other groups participated.
# Event 228577991: 14 members of own group participated and 0 members of other groups participated.
# Event 228360287: 8 members of own group participated and 0 members of other groups participated.
# Event ncxnflyvcbkc: 12 members of own group participated and 0 members of other groups participated.
# Event djmfzhyvcbxb: 26 members of own group participated and 0 members of other groups participated.
# Event 226537094: 14 members of own group participated and 0 members of other groups participated.
# Event djmfzhytpbvb: 18 members of own group participated and 0 members of other groups participated.
# Event 232560443: 3 members of own group participated and 0 members of other groups participated.
# Event 243653186: 1 members of own group participated and 0 members of other groups participated.
# Event 241001952: 39 members of own group participated and 0 members of other groups participated.
# Event 242294910: 13 members of own group participated and 0 members of other groups participated.
# Event 242568386: 11 members of own group participated and 0 members of other groups participated.
# Event 240999105: 11 members of own group participated and 0 members of other groups participated.
# Event 240849110: 39 members of own group participated and 0 members of other groups participated.
# Event 240212759: 3 members of own group participated and 0 members of other groups participated.
# Event 240096281: 37 members of own group participated and 0 members of other groups participated.
# Event 238829312: 14 members of own group participated and 0 members of other groups participated.
# Event 238039578: 44 members of own group participated and 0 members of other groups participated.
# Event 239541902: 20 members of own group participated and 0 members of other groups participated.
# Event 238829210: 9 members of own group participated and 0 members of other groups participated.
# Event 237411076: 40 members of own group participated and 0 members of other groups participated.
# Event 238273319: 8 members of own group participated and 0 members of other groups participated.
# Event 237228167: 34 members of own group participated and 0 members of other groups participated.
# Event 236703477: 11 members of own group participated and 0 members of other groups participated.
# Event 236703409: 47 members of own group participated and 0 members of other groups participated.
# Event 236650395: 18 members of own group participated and 0 members of other groups participated.
# Event 236222010: 63 members of own group participated and 0 members of other groups participated.
# Event 231864884: 20 members of own group participated and 0 members of other groups participated.
# Event 234272467: 6 members of own group participated and 0 members of other groups participated.
# Event 231864865: 16 members of own group participated and 0 members of other groups participated.
# Event 233448036: 8 members of own group participated and 0 members of other groups participated.
# Event 231864830: 14 members of own group participated and 0 members of other groups participated.
# Event 231864799: 33 members of own group participated and 0 members of other groups participated.
# Event 232646615: 18 members of own group participated and 0 members of other groups participated.
# Event 231864784: 39 members of own group participated and 0 members of other groups participated.
# Event 231777861: 21 members of own group participated and 0 members of other groups participated.
# Event 231271043: 39 members of own group participated and 0 members of other groups participated.
# Event 230714377: 24 members of own group participated and 0 members of other groups participated.
# Event 229463162: 28 members of own group participated and 0 members of other groups participated.
# Event 229031627: 37 members of own group participated and 0 members of other groups participated.
# Event 228005625: 14 members of own group participated and 0 members of other groups participated.
# Event 117878862: 61 members of own group participated and 0 members of other groups participated.
# Event 226574504: 46 members of own group participated and 0 members of other groups participated.
# Event 226548400: 28 members of own group participated and 0 members of other groups participated.
# Event 244265962: 16 members of own group participated and 0 members of other groups participated.
# Event 244316453: 2 members of own group participated and 0 members of other groups participated.
# Event 244304287: 4 members of own group participated and 0 members of other groups participated.
# Event 243280040: 8 members of own group participated and 0 members of other groups participated.
# Event 244313876: 3 members of own group participated and 0 members of other groups participated.
# Event 243279694: 11 members of own group participated and 0 members of other groups participated.
# Event 244124145: 1 members of own group participated and 0 members of other groups participated.
# Event lgbnfnywnbqb: 11 members of own group participated and 0 members of other groups participated.
# Event 243767866: 16 members of own group participated and 0 members of other groups participated.
# Event 243256854: 4 members of own group participated and 0 members of other groups participated.
# Event lgbnfnywmbsb: 11 members of own group participated and 0 members of other groups participated.
# Event 242863183: 16 members of own group participated and 0 members of other groups participated.
# Event 242516166: 7 members of own group participated and 0 members of other groups participated.
# Event 242524235: 7 members of own group participated and 0 members of other groups participated.
# Event 241791403: 29 members of own group participated and 0 members of other groups participated.
# Event 242023040: 3 members of own group participated and 0 members of other groups participated.
# Event 241913551: 1 members of own group participated and 0 members of other groups participated.
# Event lgbnfnywlbnb: 12 members of own group participated and 0 members of other groups participated.
# Event 242039955: 7 members of own group participated and 0 members of other groups participated.
# Event 241927302: 2 members of own group participated and 0 members of other groups participated.
# Event 241909011: 7 members of own group participated and 0 members of other groups participated.
# Event 241259765: 4 members of own group participated and 0 members of other groups participated.
# Event lgbnfnywkbrb: 14 members of own group participated and 0 members of other groups participated.
# Event 241182689: 4 members of own group participated and 0 members of other groups participated.
# Event 241182739: 10 members of own group participated and 0 members of other groups participated.
# Event 241096547: 7 members of own group participated and 0 members of other groups participated.
# Event 241095638: 17 members of own group participated and 0 members of other groups participated.
# Event 240852206: 12 members of own group participated and 0 members of other groups participated.
# Event 241152539: 1 members of own group participated and 0 members of other groups participated.
# Event 240474504: 5 members of own group participated and 0 members of other groups participated.
# Event 240834039: 9 members of own group participated and 0 members of other groups participated.
# Event 240710923: 1 members of own group participated and 0 members of other groups participated.
# Event 240331547: 14 members of own group participated and 0 members of other groups participated.
# Event 240420441: 8 members of own group participated and 0 members of other groups participated.
# Event lgbnfnywjblb: 10 members of own group participated and 0 members of other groups participated.
# Event 240553206: 4 members of own group participated and 0 members of other groups participated.
# Event 240419707: 3 members of own group participated and 0 members of other groups participated.
# Event 240400803: 2 members of own group participated and 0 members of other groups participated.
# Event 240301106: 5 members of own group participated and 0 members of other groups participated.
# Event 240302175: 4 members of own group participated and 0 members of other groups participated.
# Event 239332074: 10 members of own group participated and 0 members of other groups participated.
# Event 237693593: 7 members of own group participated and 0 members of other groups participated.
# Event 239708960: 5 members of own group participated and 0 members of other groups participated.
# Event 237830756: 2 members of own group participated and 0 members of other groups participated.
# Event 239616904: 3 members of own group participated and 0 members of other groups participated.
# Event 239466223: 1 members of own group participated and 0 members of other groups participated.
# Event 239444863: 5 members of own group participated and 0 members of other groups participated.
# Event 237693163: 11 members of own group participated and 0 members of other groups participated.
# Event 239090003: 6 members of own group participated and 0 members of other groups participated.
# Event 238785130: 14 members of own group participated and 0 members of other groups participated.
# Event 238774059: 15 members of own group participated and 0 members of other groups participated.
# Event 237139428: 11 members of own group participated and 0 members of other groups participated.
# Event 236864874: 12 members of own group participated and 0 members of other groups participated.
# Event 238433436: 1 members of own group participated and 0 members of other groups participated.
# Event 237692638: 9 members of own group participated and 0 members of other groups participated.
# Event 238492076: 3 members of own group participated and 0 members of other groups participated.
# Event 236864998: 6 members of own group participated and 0 members of other groups participated.
# Event 237667011: 10 members of own group participated and 0 members of other groups participated.
# Event 238117037: 2 members of own group participated and 0 members of other groups participated.
# Event 236863625: 16 members of own group participated and 0 members of other groups participated.
# Event 237831200: 1 members of own group participated and 0 members of other groups participated.
# Event 237678056: 9 members of own group participated and 0 members of other groups participated.
# Event 237657980: 1 members of own group participated and 0 members of other groups participated.
# Event 237320120: 9 members of own group participated and 0 members of other groups participated.
# Event 236864706: 4 members of own group participated and 0 members of other groups participated.
# Event 237191877: 4 members of own group participated and 0 members of other groups participated.
# Event 237282148: 4 members of own group participated and 0 members of other groups participated.
# Event 237428669: 1 members of own group participated and 0 members of other groups participated.
# Event 237005781: 12 members of own group participated and 0 members of other groups participated.
# Event 237158752: 1 members of own group participated and 0 members of other groups participated.
# Event 237142516: 2 members of own group participated and 0 members of other groups participated.
# Event 236654122: 19 members of own group participated and 0 members of other groups participated.
# Event 236450130: 1 members of own group participated and 0 members of other groups participated.
# Event 236449989: 1 members of own group participated and 0 members of other groups participated.
# Event 236253429: 4 members of own group participated and 0 members of other groups participated.
# Event 235904899: 2 members of own group participated and 0 members of other groups participated.
# Event 235675830: 9 members of own group participated and 0 members of other groups participated.
# Event 235924463: 2 members of own group participated and 0 members of other groups participated.
# Event 235608081: 6 members of own group participated and 0 members of other groups participated.
# Event 235605019: 1 members of own group participated and 0 members of other groups participated.
# Event 235542392: 6 members of own group participated and 0 members of other groups participated.
# Event 235410400: 4 members of own group participated and 0 members of other groups participated.
# Event 234995385: 1 members of own group participated and 0 members of other groups participated.
# Event 234779836: 1 members of own group participated and 0 members of other groups participated.
# Event 234867983: 3 members of own group participated and 0 members of other groups participated.
# Event 234656690: 7 members of own group participated and 0 members of other groups participated.
# Event 234645602: 9 members of own group participated and 0 members of other groups participated.
# Event 234852862: 1 members of own group participated and 0 members of other groups participated.
# Event 234440125: 8 members of own group participated and 0 members of other groups participated.
# Event 234360050: 2 members of own group participated and 0 members of other groups participated.
# Event 234276594: 1 members of own group participated and 0 members of other groups participated.
# Event 234197443: 1 members of own group participated and 0 members of other groups participated.
# Event 234205475: 1 members of own group participated and 0 members of other groups participated.
# Event 234048571: 3 members of own group participated and 0 members of other groups participated.
# Event 234184629: 1 members of own group participated and 0 members of other groups participated.
# Event 233561009: 2 members of own group participated and 0 members of other groups participated.
# Event 233662592: 5 members of own group participated and 0 members of other groups participated.
# Event 233108653: 4 members of own group participated and 0 members of other groups participated.
# Event 233225332: 9 members of own group participated and 0 members of other groups participated.
# Event 233355565: 1 members of own group participated and 0 members of other groups participated.
# Event 232812515: 7 members of own group participated and 0 members of other groups participated.
# Event 232721307: 7 members of own group participated and 0 members of other groups participated.
# Event 232757197: 2 members of own group participated and 0 members of other groups participated.
# Event 232378688: 2 members of own group participated and 0 members of other groups participated.
# Event 231987737: 7 members of own group participated and 0 members of other groups participated.
# Event 232082963: 3 members of own group participated and 0 members of other groups participated.
# Event 231819552: 2 members of own group participated and 0 members of other groups participated.
# Event 232047553: 2 members of own group participated and 0 members of other groups participated.
# Event 231746770: 7 members of own group participated and 0 members of other groups participated.
# Event 231824027: 1 members of own group participated and 0 members of other groups participated.
# Event 231713791: 3 members of own group participated and 0 members of other groups participated.
# Event 231407999: 3 members of own group participated and 0 members of other groups participated.
# Event 231596665: 3 members of own group participated and 0 members of other groups participated.
# Event 228659790: 6 members of own group participated and 0 members of other groups participated.
# Event 231363690: 10 members of own group participated and 0 members of other groups participated.
# Event 231060703: 15 members of own group participated and 0 members of other groups participated.
# Event 231105781: 1 members of own group participated and 0 members of other groups participated.
# Event 229651385: 16 members of own group participated and 0 members of other groups participated.
# Event 229651614: 16 members of own group participated and 0 members of other groups participated.
# Event 230096369: 3 members of own group participated and 0 members of other groups participated.
# Event 230213426: 1 members of own group participated and 0 members of other groups participated.
# Event 229924323: 2 members of own group participated and 0 members of other groups participated.
# Event 229831806: 8 members of own group participated and 0 members of other groups participated.
# Event 229859030: 1 members of own group participated and 0 members of other groups participated.
# Event 229622830: 1 members of own group participated and 0 members of other groups participated.
# Event 229568482: 2 members of own group participated and 0 members of other groups participated.
# Event 229471232: 1 members of own group participated and 0 members of other groups participated.
# Event 229559218: 2 members of own group participated and 0 members of other groups participated.
# Event 229561497: 1 members of own group participated and 0 members of other groups participated.
# Event 229216173: 1 members of own group participated and 0 members of other groups participated.
# Event 229370905: 2 members of own group participated and 0 members of other groups participated.
# Event 228282530: 3 members of own group participated and 0 members of other groups participated.
# Event 229016401: 1 members of own group participated and 0 members of other groups participated.
# Event 228998528: 1 members of own group participated and 0 members of other groups participated.
# Event 228727547: 3 members of own group participated and 0 members of other groups participated.
# Event 228829217: 2 members of own group participated and 0 members of other groups participated.
# Event 228310915: 8 members of own group participated and 0 members of other groups participated.
# Event 228534067: 1 members of own group participated and 0 members of other groups participated.
# Event 228328814: 18 members of own group participated and 0 members of other groups participated.
# Event 228503214: 1 members of own group participated and 0 members of other groups participated.
# Event 228310413: 3 members of own group participated and 0 members of other groups participated.
# Event 227666056: 8 members of own group participated and 0 members of other groups participated.
# Event 228005402: 4 members of own group participated and 0 members of other groups participated.
# Event 227998210: 2 members of own group participated and 0 members of other groups participated.
# Event 227666020: 1 members of own group participated and 0 members of other groups participated.
# Event 227665996: 1 members of own group participated and 0 members of other groups participated.
# Event 227665986: 1 members of own group participated and 0 members of other groups participated.
# Event 227641958: 3 members of own group participated and 0 members of other groups participated.
# Event 227490231: 4 members of own group participated and 0 members of other groups participated.
# Event 227789262: 1 members of own group participated and 0 members of other groups participated.
# Event 227785287: 2 members of own group participated and 0 members of other groups participated.
# Event 227642648: 2 members of own group participated and 0 members of other groups participated.
# Event 227578446: 5 members of own group participated and 0 members of other groups participated.
# Event 227591623: 1 members of own group participated and 0 members of other groups participated.
# Event 227533769: 2 members of own group participated and 0 members of other groups participated.
# Event 226930103: 1 members of own group participated and 0 members of other groups participated.
# Event 226813347: 4 members of own group participated and 0 members of other groups participated.
# Event 226802395: 1 members of own group participated and 0 members of other groups participated.
# Event 226687325: 13 members of own group participated and 0 members of other groups participated.
# Event 226834588: 2 members of own group participated and 0 members of other groups participated.
# Event 227063247: 1 members of own group participated and 0 members of other groups participated.
# Event 226877134: 4 members of own group participated and 0 members of other groups participated.
# Event 227052010: 1 members of own group participated and 0 members of other groups participated.
# Event 226679447: 4 members of own group participated and 0 members of other groups participated.
# Event 226742506: 1 members of own group participated and 0 members of other groups participated.
# Event 226789509: 1 members of own group participated and 0 members of other groups participated.
# Event 225969341: 14 members of own group participated and 0 members of other groups participated.
# Event 226243681: 6 members of own group participated and 0 members of other groups participated.
# Event 226071963: 13 members of own group participated and 0 members of other groups participated.
# Event 226222972: 9 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywnbnc: 1 members of own group participated and 0 members of other groups participated.
# Event 244237136: 4 members of own group participated and 0 members of other groups participated.
# Event 244465981: 3 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywnbkc: 6 members of own group participated and 0 members of other groups participated.
# Event fgggxmywnbhc: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywnbfc: 4 members of own group participated and 0 members of other groups participated.
# Event 244207416: 2 members of own group participated and 0 members of other groups participated.
# Event pqsdtnywnbbc: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywnbbc: 4 members of own group participated and 0 members of other groups participated.
# Event 244236899: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywnbvb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywnbrb: 4 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywnbpb: 1 members of own group participated and 0 members of other groups participated.
# Event fgggxmywnbpb: 3 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywnbmb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywnbjb: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywnbdb: 1 members of own group participated and 0 members of other groups participated.
# Event 243141930: 5 members of own group participated and 0 members of other groups participated.
# Event fgggxmywmbkc: 5 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywmbhc: 1 members of own group participated and 0 members of other groups participated.
# Event 243495868: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywmbdc: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywmbxb: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywmbtb: 3 members of own group participated and 0 members of other groups participated.
# Event fgggxmywmbrb: 3 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywmbrb: 1 members of own group participated and 0 members of other groups participated.
# Event 243179148: 1 members of own group participated and 0 members of other groups participated.
# Event 243179108: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywmbpb: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywmblb: 2 members of own group participated and 0 members of other groups participated.
# Event 243141837: 3 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywmbgb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywmbcb: 3 members of own group participated and 0 members of other groups participated.
# Event fgggxmywlbnc: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywlblc: 3 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywlbhc: 6 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywlbcc: 1 members of own group participated and 0 members of other groups participated.
# Event phplkmywlbxb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywlbxb: 2 members of own group participated and 0 members of other groups participated.
# Event fgggxmywlbvb: 5 members of own group participated and 0 members of other groups participated.
# Event 242467884: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywlbsb: 3 members of own group participated and 0 members of other groups participated.
# Event 242357244: 3 members of own group participated and 0 members of other groups participated.
# Event 242358754: 1 members of own group participated and 0 members of other groups participated.
# Event 242022487: 1 members of own group participated and 0 members of other groups participated.
# Event 242038264: 3 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywlbpb: 1 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywlbmb: 3 members of own group participated and 0 members of other groups participated.
# Event 242021618: 3 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywlbkb: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywlbgb: 5 members of own group participated and 0 members of other groups participated.
# Event fgggxmywlbdb: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywkbpc: 1 members of own group participated and 0 members of other groups participated.
# Event 239264617: 11 members of own group participated and 0 members of other groups participated.
# Event 242103891: 3 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywkblc: 8 members of own group participated and 0 members of other groups participated.
# Event 242021590: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywkbgc: 2 members of own group participated and 0 members of other groups participated.
# Event 241845458: 2 members of own group participated and 0 members of other groups participated.
# Event phplkmywkbcc: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywkbcc: 2 members of own group participated and 0 members of other groups participated.
# Event 241845387: 1 members of own group participated and 0 members of other groups participated.
# Event fgggxmywkbzb: 3 members of own group participated and 0 members of other groups participated.
# Event fgggxmywkbqb: 8 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywkbwb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywkbsb: 2 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywkbqb: 2 members of own group participated and 0 members of other groups participated.
# Event 241474243: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywkbnb: 2 members of own group participated and 0 members of other groups participated.
# Event 240671370: 11 members of own group participated and 0 members of other groups participated.
# Event 240671294: 6 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywkbkb: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywkbfb: 1 members of own group participated and 0 members of other groups participated.
# Event 240936213: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywjbnc: 3 members of own group participated and 0 members of other groups participated.
# Event fgggxmywjblc: 4 members of own group participated and 0 members of other groups participated.
# Event 240936167: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywjbjc: 3 members of own group participated and 0 members of other groups participated.
# Event 240451631: 3 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywjbfc: 6 members of own group participated and 0 members of other groups participated.
# Event 240897139: 6 members of own group participated and 0 members of other groups participated.
# Event 240897080: 6 members of own group participated and 0 members of other groups participated.
# Event 240417398: 5 members of own group participated and 0 members of other groups participated.
# Event 240896873: 3 members of own group participated and 0 members of other groups participated.
# Event 240671271: 4 members of own group participated and 0 members of other groups participated.
# Event 240896853: 1 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywjbzb: 1 members of own group participated and 0 members of other groups participated.
# Event 239582683: 1 members of own group participated and 0 members of other groups participated.
# Event phplkmywjbvb: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywjbvb: 2 members of own group participated and 0 members of other groups participated.
# Event fgggxmywjbsb: 4 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywjbsb: 1 members of own group participated and 0 members of other groups participated.
# Event 240452790: 3 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywjbqb: 1 members of own group participated and 0 members of other groups participated.
# Event 240452561: 1 members of own group participated and 0 members of other groups participated.
# Event 239527587: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywjbmb: 3 members of own group participated and 0 members of other groups participated.
# Event 240452240: 1 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywjbhb: 1 members of own group participated and 0 members of other groups participated.
# Event 240452193: 1 members of own group participated and 0 members of other groups participated.
# Event 240452169: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywjbdb: 5 members of own group participated and 0 members of other groups participated.
# Event fgggxmywhbpc: 3 members of own group participated and 0 members of other groups participated.
# Event 240407251: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywhbmc: 1 members of own group participated and 0 members of other groups participated.
# Event 239262876: 7 members of own group participated and 0 members of other groups participated.
# Event 239527005: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywhbjc: 7 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywhbdc: 2 members of own group participated and 0 members of other groups participated.
# Event phplkmywhbzb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywhbzb: 2 members of own group participated and 0 members of other groups participated.
# Event 239809270: 1 members of own group participated and 0 members of other groups participated.
# Event fgggxmywhbwb: 4 members of own group participated and 0 members of other groups participated.
# Event 239809534: 1 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywhbtb: 1 members of own group participated and 0 members of other groups participated.
# Event 239238067: 3 members of own group participated and 0 members of other groups participated.
# Event 239809225: 3 members of own group participated and 0 members of other groups participated.
# Event 239512045: 3 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywhbqb: 2 members of own group participated and 0 members of other groups participated.
# Event mpnzwlywhbpb: 7 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywhbnb: 1 members of own group participated and 0 members of other groups participated.
# Event 239581999: 2 members of own group participated and 0 members of other groups participated.
# Event 239512126: 2 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywhblb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywhbhb: 4 members of own group participated and 0 members of other groups participated.
# Event 239581973: 2 members of own group participated and 0 members of other groups participated.
# Event fgggxmywhbfb: 6 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywhbcb: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywgblc: 8 members of own group participated and 0 members of other groups participated.
# Event 237524120: 5 members of own group participated and 0 members of other groups participated.
# Event 239460601: 1 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywgbgc: 2 members of own group participated and 0 members of other groups participated.
# Event 239303721: 1 members of own group participated and 0 members of other groups participated.
# Event phplkmywgbcc: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywgbcc: 1 members of own group participated and 0 members of other groups participated.
# Event fgggxmywgbzb: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywgbwb: 1 members of own group participated and 0 members of other groups participated.
# Event 238748373: 3 members of own group participated and 0 members of other groups participated.
# Event 238933808: 6 members of own group participated and 0 members of other groups participated.
# Event 239174726: 3 members of own group participated and 0 members of other groups participated.
# Event mpnzwlywgbrb: 3 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywgbqb: 4 members of own group participated and 0 members of other groups participated.
# Event 238547842: 4 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywgbnb: 1 members of own group participated and 0 members of other groups participated.
# Event 239086007: 1 members of own group participated and 0 members of other groups participated.
# Event 238647597: 4 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywgbkb: 2 members of own group participated and 0 members of other groups participated.
# Event 238636193: 6 members of own group participated and 0 members of other groups participated.
# Event jjjfvmywgbfb: 2 members of own group participated and 0 members of other groups participated.
# Event 238748438: 3 members of own group participated and 0 members of other groups participated.
# Event 238854908: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywfbpc: 4 members of own group participated and 0 members of other groups participated.
# Event 238748660: 3 members of own group participated and 0 members of other groups participated.
# Event mhvtpmywfbkc: 3 members of own group participated and 0 members of other groups participated.
# Event 238726161: 3 members of own group participated and 0 members of other groups participated.
# Event 238169188: 2 members of own group participated and 0 members of other groups participated.
# Event 238169401: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywfbgc: 4 members of own group participated and 0 members of other groups participated.
# Event 238550381: 3 members of own group participated and 0 members of other groups participated.
# Event 238560148: 4 members of own group participated and 0 members of other groups participated.
# Event mhvtpmywfbbc: 2 members of own group participated and 0 members of other groups participated.
# Event 238173873: 2 members of own group participated and 0 members of other groups participated.
# Event 238169141: 5 members of own group participated and 0 members of other groups participated.
# Event 238169054: 1 members of own group participated and 0 members of other groups participated.
# Event phplkmywfbwb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywfbwb: 1 members of own group participated and 0 members of other groups participated.
# Event 238169113: 4 members of own group participated and 0 members of other groups participated.
# Event lgkwmmywfbtb: 1 members of own group participated and 0 members of other groups participated.
# Event 238421257: 1 members of own group participated and 0 members of other groups participated.
# Event mhvtpmywfbrb: 1 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywfbnb: 3 members of own group participated and 0 members of other groups participated.
# Event mpnzwlywfbmb: 1 members of own group participated and 0 members of other groups participated.
# Event bqxpfmywfbmb: 5 members of own group participated and 0 members of other groups participated.
# Event sgdnjmywfblb: 3 members of own group participated and 0 members of other groups participated.
# Event mhvtpmywfbjb: 2 members of own group participated and 0 members of other groups participated.
# Event 238105792: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywfbfb: 5 members of own group participated and 0 members of other groups participated.
# Event 237858498: 1 members of own group participated and 0 members of other groups participated.
# Event mhvtpmywdbkc: 1 members of own group participated and 0 members of other groups participated.
# Event 237633764: 2 members of own group participated and 0 members of other groups participated.
# Event qbmfjmywdbgc: 4 members of own group participated and 0 members of other groups participated.
# Event wwkzwlywdbfc: 5 members of own group participated and 0 members of other groups participated.
# Event mhvtpmywdbbc: 1 members of own group participated and 0 members of other groups participated.
# Event 237217615: 2 members of own group participated and 0 members of other groups participated.
# ...
# Event 242414347: 16 members of own group participated and 0 members of other groups participated.
# Event 243864709: 2 members of own group participated and 0 members of other groups participated.
# Event 236077825: 17 members of own group participated and 0 members of other groups participated.
# Event 243422952: 53 members of own group participated and 0 members of other groups participated.
# Event 243422671: 43 members of own group participated and 0 members of other groups participated.
# Event 243869841: 4 members of own group participated and 0 members of other groups participated.
# Event 243601678: 4 members of own group participated and 0 members of other groups participated.
# Event 242414269: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywnbfb: 12 members of own group participated and 0 members of other groups participated.
# Event 243601672: 9 members of own group participated and 0 members of other groups participated.
# Event 243776847: 1 members of own group participated and 0 members of other groups participated.
# Event 242414168: 25 members of own group participated and 0 members of other groups participated.
# Event 243127398: 29 members of own group participated and 0 members of other groups participated.
# Event 243507436: 3 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywmblc: 15 members of own group participated and 0 members of other groups participated.
# Event 243664439: 4 members of own group participated and 0 members of other groups participated.
# Event 243507424: 3 members of own group participated and 0 members of other groups participated.
# Event 242414126: 5 members of own group participated and 0 members of other groups participated.
# Event tccrfnywmbjc: 7 members of own group participated and 0 members of other groups participated.
# Event 242094262: 18 members of own group participated and 0 members of other groups participated.
# Event 243507398: 4 members of own group participated and 0 members of other groups participated.
# Event 241987626: 24 members of own group participated and 0 members of other groups participated.
# Event 243424170: 10 members of own group participated and 0 members of other groups participated.
# Event 243533555: 7 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywmbcc: 15 members of own group participated and 0 members of other groups participated.
# Event 242853237: 38 members of own group participated and 0 members of other groups participated.
# Event 243447903: 4 members of own group participated and 0 members of other groups participated.
# Event 242908243: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywmbzb: 8 members of own group participated and 0 members of other groups participated.
# Event 243298649: 2 members of own group participated and 0 members of other groups participated.
# Event 243371782: 13 members of own group participated and 0 members of other groups participated.
# Event 243308737: 6 members of own group participated and 0 members of other groups participated.
# Event 242868137: 5 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywmbsb: 10 members of own group participated and 0 members of other groups participated.
# Event 243265048: 2 members of own group participated and 0 members of other groups participated.
# Event 242868129: 4 members of own group participated and 0 members of other groups participated.
# Event 242377347: 2 members of own group participated and 0 members of other groups participated.
# Event 242868120: 3 members of own group participated and 0 members of other groups participated.
# Event 241353762: 3 members of own group participated and 0 members of other groups participated.
# Event 242868080: 4 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywmbkb: 12 members of own group participated and 0 members of other groups participated.
# Event 236077789: 18 members of own group participated and 0 members of other groups participated.
# Event 243060455: 3 members of own group participated and 0 members of other groups participated.
# Event 242867807: 4 members of own group participated and 0 members of other groups participated.
# Event 242377319: 6 members of own group participated and 0 members of other groups participated.
# Event tccrfnywmbhb: 7 members of own group participated and 0 members of other groups participated.
# Event 242900485: 6 members of own group participated and 0 members of other groups participated.
# Event 242377292: 7 members of own group participated and 0 members of other groups participated.
# Event 241334022: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywlbmc: 8 members of own group participated and 0 members of other groups participated.
# Event 242059299: 21 members of own group participated and 0 members of other groups participated.
# Event 241817323: 7 members of own group participated and 0 members of other groups participated.
# Event 241333979: 3 members of own group participated and 0 members of other groups participated.
# Event 240703730: 3 members of own group participated and 0 members of other groups participated.
# Event 242841274: 2 members of own group participated and 0 members of other groups participated.
# Event 241333929: 5 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywlbgc: 11 members of own group participated and 0 members of other groups participated.
# Event 242750845: 8 members of own group participated and 0 members of other groups participated.
# Event 241333893: 2 members of own group participated and 0 members of other groups participated.
# Event 242372607: 6 members of own group participated and 0 members of other groups participated.
# Event 160315242: 68 members of own group participated and 0 members of other groups participated.
# Event 242445300: 8 members of own group participated and 0 members of other groups participated.
# Event 240703595: 17 members of own group participated and 0 members of other groups participated.
# Event 242526053: 13 members of own group participated and 0 members of other groups participated.
# Event 240121947: 48 members of own group participated and 0 members of other groups participated.
# Event 241333839: 3 members of own group participated and 0 members of other groups participated.
# Event 241824558: 30 members of own group participated and 0 members of other groups participated.
# Event 242560134: 7 members of own group participated and 0 members of other groups participated.
# Event 241333812: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywlbtb: 10 members of own group participated and 0 members of other groups participated.
# Event 242372474: 3 members of own group participated and 0 members of other groups participated.
# Event 241333787: 5 members of own group participated and 0 members of other groups participated.
# Event 242134901: 22 members of own group participated and 0 members of other groups participated.
# Event 241876467: 3 members of own group participated and 0 members of other groups participated.
# Event 241333765: 4 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywlbnb: 18 members of own group participated and 0 members of other groups participated.
# Event 242339485: 13 members of own group participated and 0 members of other groups participated.
# Event 241333744: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywlblb: 17 members of own group participated and 0 members of other groups participated.
# Event 242224339: 1 members of own group participated and 0 members of other groups participated.
# Event 241086937: 18 members of own group participated and 0 members of other groups participated.
# Event 241817297: 13 members of own group participated and 0 members of other groups participated.
# Event 241333731: 3 members of own group participated and 0 members of other groups participated.
# Event 241697811: 7 members of own group participated and 0 members of other groups participated.
# Event 242211540: 13 members of own group participated and 0 members of other groups participated.
# Event 241333682: 3 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywlbfb: 22 members of own group participated and 0 members of other groups participated.
# Event 242094452: 8 members of own group participated and 0 members of other groups participated.
# Event 241333657: 4 members of own group participated and 0 members of other groups participated.
# Event 241713333: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywlbcb: 15 members of own group participated and 0 members of other groups participated.
# Event 241096939: 27 members of own group participated and 0 members of other groups participated.
# Event 241779922: 1 members of own group participated and 0 members of other groups participated.
# Event 241699489: 3 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywkbkc: 23 members of own group participated and 0 members of other groups participated.
# Event 241975422: 5 members of own group participated and 0 members of other groups participated.
# Event 240906438: 2 members of own group participated and 0 members of other groups participated.
# Event 241713271: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywkbhc: 7 members of own group participated and 0 members of other groups participated.
# Event 238963433: 14 members of own group participated and 0 members of other groups participated.
# Event 241096926: 22 members of own group participated and 0 members of other groups participated.
# Event 240906426: 4 members of own group participated and 0 members of other groups participated.
# Event 240740752: 61 members of own group participated and 0 members of other groups participated.
# Event 241873899: 13 members of own group participated and 0 members of other groups participated.
# Event 241390365: 10 members of own group participated and 0 members of other groups participated.
# Event 241798082: 3 members of own group participated and 0 members of other groups participated.
# Event 241864638: 7 members of own group participated and 0 members of other groups participated.
# Event 241699468: 3 members of own group participated and 0 members of other groups participated.
# Event 240906415: 2 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywkbbc: 20 members of own group participated and 0 members of other groups participated.
# Event 240906411: 3 members of own group participated and 0 members of other groups participated.
# Event 241712088: 8 members of own group participated and 0 members of other groups participated.
# Event tccrfnywkbxb: 15 members of own group participated and 0 members of other groups participated.
# Event 241096916: 23 members of own group participated and 0 members of other groups participated.
# Event 240906406: 2 members of own group participated and 0 members of other groups participated.
# Event 240998171: 5 members of own group participated and 0 members of other groups participated.
# Event 241305527: 3 members of own group participated and 0 members of other groups participated.
# Event 241710803: 8 members of own group participated and 0 members of other groups participated.
# Event 241699444: 6 members of own group participated and 0 members of other groups participated.
# Event 240906396: 3 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywkbrb: 11 members of own group participated and 0 members of other groups participated.
# Event 241545584: 12 members of own group participated and 0 members of other groups participated.
# Event 240906385: 3 members of own group participated and 0 members of other groups participated.
# Event tccrfnywkbpb: 15 members of own group participated and 0 members of other groups participated.
# Event 241096902: 16 members of own group participated and 0 members of other groups participated.
# Event 240906372: 3 members of own group participated and 0 members of other groups participated.
# Event 236077737: 53 members of own group participated and 0 members of other groups participated.
# Event 241084798: 21 members of own group participated and 0 members of other groups participated.
# Event 241375704: 11 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywkbjb: 19 members of own group participated and 0 members of other groups participated.
# Event 240900936: 11 members of own group participated and 0 members of other groups participated.
# Event 241301680: 3 members of own group participated and 0 members of other groups participated.
# Event 240906348: 2 members of own group participated and 0 members of other groups participated.
# Event 241279730: 1 members of own group participated and 0 members of other groups participated.
# Event 241096620: 19 members of own group participated and 0 members of other groups participated.
# Event 240906320: 8 members of own group participated and 0 members of other groups participated.
# Event 240894157: 26 members of own group participated and 0 members of other groups participated.
# Event 240668227: 6 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywjbmc: 19 members of own group participated and 0 members of other groups participated.
# Event 241106263: 2 members of own group participated and 0 members of other groups participated.
# Event tccrfnywjbkc: 10 members of own group participated and 0 members of other groups participated.
# Event 240499570: 18 members of own group participated and 0 members of other groups participated.
# Event 240372593: 18 members of own group participated and 0 members of other groups participated.
# Event 240895647: 14 members of own group participated and 0 members of other groups participated.
# Event 241032198: 11 members of own group participated and 0 members of other groups participated.
# Event 240643745: 4 members of own group participated and 0 members of other groups participated.
# Event 240936797: 4 members of own group participated and 0 members of other groups participated.
# Event 241003022: 12 members of own group participated and 0 members of other groups participated.
# Event 240899318: 7 members of own group participated and 0 members of other groups participated.
# Event 240668192: 2 members of own group participated and 0 members of other groups participated.
# Event tccrfnywjbbc: 9 members of own group participated and 0 members of other groups participated.
# Event 238963410: 19 members of own group participated and 0 members of other groups participated.
# Event 240868542: 9 members of own group participated and 0 members of other groups participated.
# Event 240668174: 2 members of own group participated and 0 members of other groups participated.
# Event 239860054: 54 members of own group participated and 0 members of other groups participated.
# Event 240730923: 10 members of own group participated and 0 members of other groups participated.
# Event 240848472: 1 members of own group participated and 0 members of other groups participated.
# Event 240792957: 4 members of own group participated and 0 members of other groups participated.
# Event 240776561: 13 members of own group participated and 0 members of other groups participated.
# Event 240315974: 4 members of own group participated and 0 members of other groups participated.
# Event qvbrfnywjbtb: 18 members of own group participated and 0 members of other groups participated.
# Event 240754899: 5 members of own group participated and 0 members of other groups participated.
# Event 240315962: 3 members of own group participated and 0 members of other groups participated.

# %%
x_labels = [f"Event {event_id}" for event_id in event_participation.keys()]
own_group_counts = [participation['own_group_count'] for participation in event_participation.values()]
other_group_counts = [participation['other_group_count'] for participation in event_participation.values()]

x = range(len(x_labels))
width = 0.4

fig, ax = plt.subplots()
own_group_bars = ax.bar(x, own_group_counts, width, label='Own group')
other_group_bars = ax.bar([i + width for i in x], other_group_counts, width, label='Other groups')

ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(x_labels)
ax.set_ylabel('Number of members')
ax.set_title('Member Participation by Group')
ax.legend()

plt.show()

# %%
# Counting members who have attended 1 event and members who attended more than 1 event
# Members having membership have been attended more than 1 event
rsvps_group = (rsvps.groupby(['member_id', 'group_id']).size()
                   .reset_index().rename(columns={0: 'weight'}) )
rsvps_group['membership'] = rsvps_group.weight > 1

n_filt, n_keep = rsvps_group.membership.value_counts().values
print('{} members had only attended one event in a group and \n{} members had attended more than one  events.'.format(n_filt, n_keep))

# rsvps_group.head()
# Out:
# 27588 members had only attended one event in a group and
# 17995 members had attended more than one  events.

# %%
# Graph of members who have attended more than 1 events
g = nx.from_pandas_edgelist(rsvps_group.loc[rsvps_group.membership==True], 
                             'member_id', 'group_id', ['weight'])
node_type_dict = {n: ('member' if n in members.index else 'group') 
                        for n in g.nodes}
nx.set_node_attributes(g, node_type_dict, 'node_type')
# pos = nx.spring_layout(g)
# nx.draw_networkx(g, pos,node_size=8,
#                        with_labels=False)

# plt.show()

# %%
components = nx.connected_components(g)
components = sorted(list(components), key=len)
component_lengths = [len(x) for x in components]
g = nx.subgraph(g, components[-1])

# %%
# Dividing members and groups
member_nodes, group_nodes = nx.bipartite.sets(g)
gm = nx.bipartite.weighted_projected_graph(g, member_nodes, ratio=False)
# pos = nx.spring_layout(gm)
# nx.draw_networkx(gm, pos, node_size=8,
#                        with_labels=False)
# plt.show()

# %%
def get_graph_measures(centrality_subset_ratio=0.25):
    # Initialize our dataframe
    df = pd.DataFrame(index=gm.nodes)
    df['in_nashjs'] = [True if n in nashjs_member_ids 
                                   else False for n in gm.nodes]

    # Add in "group" degree from the original graph
    df['num_groups'] = pd.Series(dict(nx.degree(g, member_nodes)))

    # Get member-graph measures
    df['degree'] = pd.Series(dict(nx.degree(gm)))
    
    # Centrality, especially betweenness centrality, is an intensive calculation
    subset_size = np.floor(centrality_subset_ratio * len(g.nodes)).astype(int)
    centrality = nx.betweenness_centrality(gm, k=subset_size, weight='weight')
    df['centrality'] = pd.Series(centrality)

    # Save the member information to csv
    df.to_csv('/content/drive/MyDrive/SNA /datasets-1/nashville_graph_data.csv', encoding='utf8')
    
    return df

overwrite = False
if overwrite == True:
    df_members = get_graph_measures(0.25)
if overwrite == False:
    df_members = pd.read_csv('/content/drive/MyDrive/SNA /datasets-1/nashville_graph_data.csv', index_col='member_id')

# %%
#Details of members participated in events of which groups
def member_details(member_id,  num_groups=5):
    gdict = {targ: attr['weight'] for src,targ,attr in g.edges(member_id, data=True)}
    gdf = (pd.DataFrame.from_dict(gdict, orient='index')
               .rename(columns={0: 'events_attended'})
               .join(groups).sort_values(by='events_attended', ascending=False) )

    gdf[['group_name', 'events_attended']]
    
    report_str = '{} ({}) is a member of {} groups.\n'.format(members.loc[member_id, 'name'], member_id, gdf.shape[0])
    report_str += 'Topmost events attended are:\n'
    max_groups = num_groups if (gdf.shape[0] >= num_groups) else gdf.shape[0]
    for ind, s in gdf.iloc[0:max_groups].iterrows():
        report_str += '- {}: {}\n'.format(s.group_name, s.events_attended)
        
    print(report_str)

# %%
nashville_famous_members = (df_members.sort_values(by='centrality', ascending=False)
                    .join(members['name']).iloc[0:5]
                    [['name', 'degree', 'centrality']] )
nashville_famous_members
# Out:
#                     name  degree  centrality
# member_id
# 3949436            Pablo    1377    0.019059
# 8539046          Shalini    1911    0.018181
# 5900662    Matt Kenigson    1811    0.016951
# 197928971            Ted    1620    0.015200
# 175300482            Rav    1556    0.014787

# %%
member_details(3949436, 8)
# Out:
# Pablo (3949436) is a member of 16 groups.
# Topmost events attended are:
# - Eat Love Nash: 9
# - Nashvegans!: 6
# - 20&UP Tennis: Nashville: 6
# - Nashville Spanish Meetup: 5
# - Spiritual Psychology and Consciousness Group: 5
# - Nashville Pilgrimage Hiking & Walking Meetup Group: 5
# - The Joy of Dining Out with Friends Meetup: 4
# - Nashville Tennis Meetup: 4

# %% [markdown]
# BELOW COMMUNITY DETECTION CODE WRITTEN BY NEEL

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from community import community_louvain
from datetime import datetime
from IPython.display import display

# Load the datasets
group_edges = pd.read_csv('group-edges.csv')
meta_events = pd.read_csv('meta-events.csv')
member_to_group_edges = pd.read_csv('member-to-group-edges.csv')
meta_groups = pd.read_csv('meta-groups.csv')
rsvps = pd.read_csv('rsvps.csv')

# Conversion of timestamp into datetime format
meta_events['time'] = pd.to_datetime(meta_events['time'])

# Merging meta_groups and meta_events
meta_events = meta_events.merge(meta_groups, on='group_id')


# Calculate the #number of members for each group
#it is possible that a member can be present in multiple groups
total_members = member_to_group_edges.groupby('group_id')['member_id'].nunique()

# Function to create a graph based on events up to a specific date
def create_graph_on_date(date):
    # Filter events up to the given date
    events_upto_date = meta_events[meta_events['time'] <= date]

    # The `rsvps_upto_date`: flitered data set to include only events that occurred on or before specified date
    # Further this filtered data set will be merge with meta_events and member_to_group_edges and then
    # This data set is then used to create the graph of group relationships.
    rsvps_upto_date = rsvps.merge(events_upto_date, on='event_id')
    rsvps_upto_date = rsvps_upto_date.merge(member_to_group_edges[['member_id', 'group_id']], on='member_id')
    


    # Group by member and group IDs, and aggregate by counting the number of events attended in each group
    member_to_group_edges_upto_date = rsvps_upto_date.groupby(['member_id', 'group_id']).size().reset_index(name='weight')

    # Merging filtered member-to-group edges and group_edges
    group_edges_upto_date = group_edges.merge(member_to_group_edges_upto_date, left_on='group1', right_on='group_id')
    group_edges_upto_date = group_edges_upto_date.merge(member_to_group_edges_upto_date, left_on=['group2', 'member_id'], right_on=['group_id', 'member_id'])
    

    # Create the graph from the filtered group_edges_upto_date
    G = nx.from_pandas_edgelist(group_edges_upto_date, source='group1', target='group2', edge_attr='weight')

    return G, member_to_group_edges_upto_date, rsvps_upto_date


# Define the cluster_info function
def cluster_info(G, partition, rsvps_upto_date, total_members):
    #dictionary to store cluster information
    cluster_summary = {}

    for node, cluster_id in partition.items():
        if cluster_id not in cluster_summary:
            cluster_summary[cluster_id] = {'nodes': [], 'total_weight': 0}
        cluster_summary[cluster_id]['nodes'].append(node)

    # Iterate over the cluster_summary dictionary to calculate the total weight of the edges within each cluster. 
    # Update the total_weight value in the cluster_summary dictionary.
    for cluster_id, info in cluster_summary.items():
        total_weight = 0
        for node1 in info['nodes']:
            for node2 in info['nodes']:
                if G.has_edge(node1, node2):
                    total_weight += G[node1][node2]['weight'] # fpr ed
        cluster_summary[cluster_id]['total_weight'] = total_weight // 2

    cluster_df = pd.DataFrame.from_dict(cluster_summary, orient='index') #Create a DataFrame cluster_df from the cluster_summary dictionary with clusters as index.
    cluster_df.index.name = 'Cluster ID'
    cluster_df.reset_index(inplace=True)
    #lambda function: takes input of nodes list and returns value of lenght of list 
    cluster_df['Number of Nodes'] = cluster_df['nodes'].apply(lambda x: len(x)) #apply() is a method of a pandas DataFrame that allows you to apply a function to each row or column of the DataFrame.

    #group names and attendance percentages adding to the cluster
    cluster_df['group_names'] = cluster_df['nodes'].apply(lambda nodes: [meta_groups.loc[meta_groups['group_id'] == node, 'group_name'].values[0] for node in nodes])
    total_members_dict = total_members.to_dict() #Convert the total_members DataFrame into a dictionary.
    cluster_df['attendance_percentages'] = cluster_df['nodes'].apply(lambda nodes: [calculate_attendance_percentage(node, rsvps_upto_date, total_members_dict) for node in nodes])

    return cluster_df[['Cluster ID', 'Number of Nodes', 'total_weight', 'nodes', 'group_names', 'attendance_percentages']]

# Select the time points at which you want to analyze the community evolution
time_points = pd.date_range(meta_events['time'].min(), meta_events['time'].max(), periods=3)

def get_top_groups(row, n=3):
    combined = list(zip(row['group_names']))
    combined.sort(key=lambda x: x[0], reverse=True)
    return combined[:n]

# Function to calculate the percentage of group members who attended the meeting for each group
def calculate_attendance_percentage(group_id, rsvps_upto_date, total_members):
    attended_members = rsvps_upto_date[rsvps_upto_date['group_id'] == group_id]['member_id'].nunique()
    return (attended_members / total_members[group_id]) * 100

# Analyze community evolution at the selected time points
for time_point in time_points:
    print(f"Community evolution on {time_point.strftime('%Y-%m-%d')}:")
    G, member_to_group_edges_upto_date, rsvps_upto_date = create_graph_on_date(time_point) #unpack the tuple
    partition = community_louvain.best_partition(G)

    # Plot the community structure at this particular time point
    pos = nx.spring_layout(G, seed=42)
    colors = ['red', 'blue', 'green', 'yellow', 'purple', 'orange', 'cyan', 'magenta', 'pink', 'grey']
    num_clusters = len(set(partition.values()))
    for cluster_id in range(num_clusters):
        node_list = [node for node, membership in partition.items() if membership == cluster_id] #This line creates a list of nodes that belong to the current cluster being iterated over. 
        nx.draw_networkx_nodes(G, pos, nodelist=node_list, node_color=colors[cluster_id], node_size=50)
        # nx.draw_networkx_labels(G, pos, labels={node: node for node in node_list}, font_size=8)
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    plt.show()

    # Cluster information table
    cluster_df = cluster_info(G, partition, rsvps_upto_date, total_members)
    print("Cluster information table:")
    display(cluster_df)
    cluster_df['top_groups'] = cluster_df.apply(get_top_groups, axis=1)
    top_groups_df = cluster_df[['Cluster ID', 'top_groups']]

    # Displaying top_group
    print("Top 3 groups is respective cluster")
    display(top_groups_df)
    # -----------------------------------------------------------------------------

    print("\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-d565784b589c> in <cell line: 9>()
#       7
#       8 # Load the datasets
# ----> 9 group_edges = pd.read_csv('group-edges.csv')
#      10 meta_events = pd.read_csv('meta-events.csv')
#      11 member_to_group_edges = pd.read_csv('member-to-group-edges.csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'group-edges.csv'

# %% [markdown]
# BELOW TEMPORAL NETWORK ANALYSIS WRITTEN BY NIHAR

# %%
# Temporal Network Analysis 
#Or
#Analysis of network with respect to time
'''
Temporal Analysis of Events And Members
'''

import pandas as pd
import matplotlib.pyplot as plt

# load data
events_df = pd.read_csv('meta-events.csv')
edges_df = pd.read_csv('member-to-group-edges.csv')

# convert time column to datetime format
events_df['time'] = pd.to_datetime(events_df['time'], format='%Y/%m/%d %H:%M:%S')

# create table of total events per month
events_df['year_month'] = events_df['time'].dt.to_period('M')
events_count_month = events_df.groupby('year_month')['event_id'].count().reset_index()
events_count_month.rename(columns={'event_id': 'total_events'}, inplace=True)

# create table of unique members per month
edges_df['year_month'] = pd.to_datetime(events_df['time'], format='%Y/%m/%d %H:%M:%S').dt.to_period('M')
unique_members_month = edges_df.groupby('year_month')['member_id'].nunique().reset_index()
unique_members_month.rename(columns={'member_id': 'unique_members'}, inplace=True)

# convert year_month column to string format
analysis_df['year_month_str'] = analysis_df['year_month'].dt.strftime('%Y-%m')

# plot graph of total events and unique members per month
plt.figure(figsize=(10, 6))
plt.plot(analysis_df['year_month_str'], analysis_df['total_events'], label='Total events')
plt.plot(analysis_df['year_month_str'], analysis_df['unique_members'], label='Unique members')
plt.xticks(rotation=45)
plt.title('Temporal analysis of events and members')
plt.xlabel('Year-Month')
plt.ylabel('Count')
plt.legend()
plt.show()

# print tables for better clarification
print('Total events per month:')
print(events_count_month.to_string(index=False))

print('\nUnique members per month:')
print(unique_members_month.to_string(index=False))

print('\nAnalysis table:')
print(analysis_df.to_string(index=False))

# %%
# Load data
rsvps = pd.read_csv('rsvps.csv')
meta_events = pd.read_csv('meta-events.csv')

# Convert the timestamp column to a datetime object and filter events for December 2015
meta_events['time'] = pd.to_datetime(meta_events['time'])
december_2015_events = meta_events[(meta_events['time'].dt.year == 2015) & (meta_events['time'].dt.month == 12)]

# Merge the December 2015 events with the RSVPs data
rsvps_december_2015 = rsvps[rsvps['event_id'].isin(december_2015_events['event_id'])]

# Calculate the number of attendees for each event
event_attendees = rsvps_december_2015.groupby('event_id')['member_id'].nunique().reset_index()
event_attendees.columns = ['event_id', 'num_attendees']

# Merge the number of attendees with event metadata and sort by the number of attendees in ascending order
least_popular_events = december_2015_events.merge(event_attendees, on='event_id').sort_values('num_attendees')

# Display the resulting table
least_popular_events[['event_id', 'name', 'time', 'num_attendees']]

# %%
# Read in the data
group_edges = pd.read_csv('group-edges.csv')
member_edges = pd.read_csv('member-edges.csv')
member_group_edges = pd.read_csv('member-to-group-edges.csv')
meta_groups = pd.read_csv('meta-groups.csv', index_col='group_id')
meta_members = pd.read_csv('meta-members.csv', index_col='member_id')
meta_events = pd.read_csv('meta-events.csv', index_col='event_id')
rsvps = pd.read_csv('rsvps.csv')

# Create member-to-group bipartite graph
G_mb = nx.Graph()
for i, row in member_group_edges.iterrows():
    G_mb.add_edge(row['member_id'], row['group_id'], weight=row['weight'])

# Create group-to-group graph
G_gg = nx.Graph()
for i, row in group_edges.iterrows():
    G_gg.add_edge(row['group1'], row['group2'], weight=row['weight'])

# Create member-to-member graph
G_mm = nx.Graph()
for i, row in member_edges.iterrows():
    G_mm.add_edge(row['member1'], row['member2'], weight=row['weight'])

    
#This part of the code loads the meta-events.csv file and performs a longitudinal analysis on the number of events per month.
import pandas as pd
import matplotlib.pyplot as plt

# Load the meta-events.csv file
df_events = pd.read_csv("meta-events.csv")

# Convert the time column to a datetime object
df_events["time"] = pd.to_datetime(df_events["time"])

# Group the events by year and month
df_events["year_month"] = df_events["time"].apply(lambda x: f"{x.year}-{x.month:02}")
df_events_grouped = df_events.groupby("year_month").size().reset_index(name="count")
#creates a new column year_month in the df_events DataFrame using a 
#lambda function that extracts the year and month from the time column and formats it as a string in the form "YYYY-MM".
#The groupby method is used to group the events by year_month, and the size method is used to count the number of events in each group. 
# The reset_index method is used to convert the resulting grouped Series back to a DataFrame and reset the index. 
# The resulting DataFrame is stored in the variable df_events_grouped

# Plot the graph of number of events per month
plt.plot(df_events_grouped["year_month"], df_events_grouped["count"])
plt.xticks(rotation=90)
plt.xlabel("Year-Month")
plt.ylabel("Number of Events")
plt.title("Longitudinal Analysis of Number of Events")
plt.show()
#create a line plot of the number of events per month using plt.plot.
# The x-axis values are the year_month column of the df_events_grouped DataFrame, and the y-axis values are the count column. 
# The plt.xticks function rotates the x-axis tick labels by 90 degrees to avoid overlapping. 
# The plt.xlabel, plt.ylabel, and plt.title functions set the axis labels and title of the plot. The plt.show function displays the plot.
